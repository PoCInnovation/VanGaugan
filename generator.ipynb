# %%
import torch

# %%
x = torch.empty(5, 3)
print(x)
# Out:
# tensor([[2.7082e+23, 6.7061e+22, 1.1040e-05],
#         [2.6408e-06, 4.2657e-08, 1.1966e+22],
#         [3.1097e-18, 6.4805e-10, 6.3006e-10],
#         [1.0255e-08, 6.8738e-04, 4.3357e-08],
#         [2.7147e-06, 2.6513e-09, 2.3329e-18]])
